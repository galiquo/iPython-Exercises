# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
from ggplot import *

# %%
years = range(1880, 2014)

dirName = '/Users/gabrielaliquo/pythongame/names/'

pieces = []
columns = ['name','sex','births']

for year in years:
    path = dirName + 'yob%d.txt' % year
    frame = pd.read_csv(path, names=columns)
    frame['year'] = year
    frame['age'] = 2015 - year
    pieces.append(frame)

names = pd.concat(pieces, ignore_index=True)

# %%
print names.head(n=10)
# Out:
#         name sex  births  year  age
# 0       Mary   F    7065  1880  135
# 1       Anna   F    2604  1880  135
# 2       Emma   F    2003  1880  135
# 3  Elizabeth   F    1939  1880  135
# 4     Minnie   F    1746  1880  135
# 5   Margaret   F    1578  1880  135
# 6        Ida   F    1472  1880  135
# 7      Alice   F    1414  1880  135
# 8     Bertha   F    1320  1880  135
# 9      Sarah   F    1288  1880  135

# %%
NameList = ['Matthew', 'Erica', 'Francis', 'Zachary', 'Emily', 'Gabriel', 'Audrey', 'Judith', 'Erin', 'James']

# %%
Hoovers = names[names.name.isin(NameList)]

# %%
agepivot = Hoovers.pivot_table('births', index='age', columns='name')
print agepivot.head(n=10)
# Out:
# name  Audrey    Emily   Erica    Erin  Francis  Gabriel   James  Judith  \
# age
# 2     2790.0   6532.0   515.0   603.5    293.5   5582.5  6722.0     249
# 3     2648.5   6813.5   604.0   643.5    236.5   5787.5  6689.5     292
# 4     2606.5   7119.5   621.0   702.0    218.5   6194.5  6622.5     313
# 5     2478.0   7138.0   741.0   748.5    201.5   6474.0  6931.0     302
# 6     2506.5   7676.0   938.0   878.5    206.0   6470.5  7110.5     370
# 7     2723.5   8722.5  1131.0  1064.5    219.5   6580.0  7587.5     416
# 8     2628.5   9683.5  1364.0  1272.5    238.5   6528.5  7985.0     453
# 9     2327.0  10708.0  1547.0  1357.5    255.5   6349.0  8135.5     505
# 10    2071.5  11979.0   861.5  1487.5    263.5   6462.0  8072.0     525
# 11    1959.0  12570.0   941.5  1727.5    263.0   5889.5  8270.5     529
#
# name  Matthew  Zachary
# age
# 2      6621.0   2845.5
# 3      6969.0   3119.5
# 4      7079.0   3396.5
# 5      7053.5   3584.0
# 6      7988.5   4040.5
# 7      8795.5   4616.0
# 8      9371.0   5110.5
# 9     10165.5   5510.5
# 10    10742.5   6149.0
# 11    11485.5   6888.0

# %%
agepivot.plot(title='Hoovers/Aliquo Age').legend(loc='center left', bbox_to_anchor=(1, 0.5))
